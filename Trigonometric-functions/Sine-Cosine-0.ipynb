# %%
# 程式碼A區==程式碼A區==程式碼A區==程式碼A區==程式碼A區
# AAAAAAAA==AAAAAAAA==AAAAAAAAA==AAAAAAAA==AAAAAAAA
#
# Sine-Cosine-0
# 2021-10-20
#
# python 3.8
# run on https://replit.com
# run on ubuntu 16.04 LTS
#
# 要執行本程式, 請按上方run▶
#
# Browser encoding UTF-8 HTML5 URL / as %2F
#
# 程式碼B區==程式碼B區==程式碼B區==程式碼B區==程式碼B區
# BBBBBBBB==BBBBBBBB==BBBBBBBBB==BBBBBBBB==BBBBBBBB
#
# to fix matplotlib warning
import os
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
#
import sys
#
# 載入繪圖模組 pyplot, 重新命名為 plot
import matplotlib.pyplot as plot
import numpy as np
from shapely.geometry  import LineString
#
# 定義圖面函數 ------------------------------------------------------
def set_graphic_area(width,height) :
    #    
    cm2inch = 1/2.54    # inch per cm
    #
    # define graphic area
    #
    left_margin  = 2.0  # cm
    right_margin = 1.0  # cm
    #
    figure_width  = width  # cm , from xmin to xmax
    figure_height = height # cm , from ymin to ymax
    #
    top_margin = 1.0    # cm
    bottom_margin = 1.0 # cm
    #
    box_width = left_margin + figure_width + right_margin   # cm
    box_height = top_margin + figure_height + bottom_margin # cm
    #
    top_value    = 1.0 - top_margin / box_height
    bottom_value = bottom_margin / box_height
    left_value   = left_margin / box_width
    right_value  = 1.0 - right_margin / box_width
    #
    return (box_width*cm2inch,box_height*cm2inch,top_value,bottom_value,left_value,right_value,width)
#
# end of def
#
# Define the arc
# center position is cxy = (cx, cy)
# start_angle, end_angle is in degrees
#
def shapely_Arc(cxy, r, start_angle, end_angle) :
    #
    numsegments = 1440
    # The coordinates of the arc
    theta = np.radians(np.linspace(start_angle, end_angle, numsegments))
    x = cxy[0] + r * np.cos(theta)
    y = cxy[1] + r * np.sin(theta)
    Arc = LineString(np.column_stack([x, y]))
    return Arc
    #
# end of def
#
def motif_line_1(LS, COLOR, ZORDER, LINEWIDTH) :
    #
    xs, ys = LS.xy
    ax_1.plot(xs, ys, color=COLOR, alpha=0.7, linewidth=LINEWIDTH, solid_capstyle='round', zorder=ZORDER)
    return
#
def motif_line_2(LS, COLOR, ZORDER, LINEWIDTH) :
    #
    xs, ys = LS.xy
    ax_2.plot(xs, ys, color=COLOR, alpha=0.7, linewidth=LINEWIDTH, solid_capstyle='round', zorder=ZORDER)
    return
#
def motif_fill(LS, COLOR, ZORDER, ALPHA) :
    #
    xs, ys = LS.xy
    ax_1.fill(xs, ys, alpha=ALPHA, closed=True, edgecolor=None, facecolor=COLOR, fill=True, joinstyle='miter', zorder=ZORDER)
    return
#
# 程式碼C區==程式碼C區==程式碼C區==程式碼C區==程式碼C區
# CCCCCCCC==CCCCCCCC==CCCCCCCCC==CCCCCCCC==CCCCCCCC
#
# 設定圖面大小
#  setup圖面大小 (10,5) 單位公分
#  tup7 is type of Tuple, have 7 indexed value
#
# main()
tup7 = set_graphic_area(4*np.pi,8)  
# 呼叫 pyplot.figure(), 建立一個圖表物件, 並成為目前圖表物件
fig = plot.figure(figsize=(tup7[0], tup7[1])) 
# 圖表的繪圖區域被分為1個子圖, 1 row, 1 column, plot to index 1
ax_1 = fig.add_subplot(2,1,1)   
fig.subplots_adjust(
                top    = tup7[2] ,
                bottom = tup7[3] ,
                left   = tup7[4] ,
                right  = tup7[5] ,
                )
#
plot.xlim(-2*np.pi, 2*np.pi)    # 設定X軸的顯示範圍, from xmin to xmax
plot.ylim(-1.5, 1.5)            # 設定Y軸的顯示範圍, from ymin to ymax
#
xvalues = [-2*np.pi, -3*np.pi/2, -1*np.pi, -1*np.pi/2, 0,
            1*np.pi/2, 1*np.pi, 3*np.pi/2, 2*np.pi]
#
yvalues = [-1.5,-1,-0.5,0,0.5,1,1.5]
#
plot.xticks(xvalues)
plot.yticks(yvalues)
plot.tick_params(labelsize=6)
#
plot.xlabel("x")
plot.ylabel("sin(x)")
#
# get current axes, set X,Y same ratio & scale 
# 'equal' --> 0.5
plot.gca().set_aspect('equal', adjustable='box')
#
plot.grid(color='green', linewidth=0.5)
ax_1.grid(True)
# ax.grid(False)
ax_1.set_axis_on() # will turn on  grid line
# ax.set_axis_off()  # will turn off grid line
#
plot.savefig("./png/1-1.png", format="png", dpi=150)
#
# 程式碼D區==程式碼D區==程式碼D區==程式碼D區==程式碼D區
# DDDDDDDD==DDDDDDDD==DDDDDDDDD==DDDDDDDD==DDDDDDDD
#
numsegments = 1441
x_coords_degree = np.linspace(-360, 360, numsegments)
x_coords_radian = np.round(np.radians(x_coords_degree), decimals=4) 
print(x_coords_degree)
print(x_coords_radian)
#
# The coordinates of the Sine
x = x_coords_radian
y = np.sin(x)
list_of_list = np.column_stack((x, y))
print(list_of_list)
#
"""
>>> a = np.array((1,2,3))
>>> b = np.array((2,3,4))
>>> np.column_stack((a,b))
array([[1, 2],
       [2, 3],
       [3, 4]])
"""
list_of_tuple = [tuple(xy) for xy in list_of_list]
print(list_of_tuple)
#
Sine = LineString(list_of_tuple)
motif_line_1(Sine, 'blue', 10, 1.2)
#
plot.savefig("./png/1-2.png", format="png", dpi=150)
#
ax_2 = fig.add_subplot(2,1,2)   
fig.subplots_adjust(
                top    = tup7[2] ,
                bottom = tup7[3] ,
                left   = tup7[4] ,
                right  = tup7[5] ,
                )
#
plot.xlim(-2*np.pi, 2*np.pi)    # 設定X軸的顯示範圍, from xmin to xmax
plot.ylim(-1.5, 1.5)            # 設定Y軸的顯示範圍, from ymin to ymax
#
xvalues = [-2*np.pi, -3*np.pi/2, -1*np.pi, -1*np.pi/2, 0,
            1*np.pi/2, 1*np.pi, 3*np.pi/2, 2*np.pi]
#
yvalues = [-1.5,-1,-0.5,0,0.5,1,1.5]
#
plot.xticks(xvalues)
plot.yticks(yvalues)
plot.tick_params(labelsize=6)
#
plot.xlabel("x")
plot.ylabel("cos(x)")
#
# get current axes, set X,Y same ratio & scale 
plot.gca().set_aspect('equal', adjustable='box')
#
plot.grid(color='green', linewidth=0.5)
ax_2.grid(True)
# ax.grid(False)
ax_2.set_axis_on() # will turn on  grid line
# ax.set_axis_off()  # will turn off grid line
#
plot.savefig("./png/1-3.png", format="png", dpi=150)
#
# The coordinates of the Cosine
x = x_coords_radian
y = np.cos(x)
list_of_list  = np.column_stack((x, y))
list_of_tuple = [tuple(xy) for xy in list_of_list]
Cosine = LineString(list_of_tuple)
motif_line_2(Cosine, 'magenta', 10, 1.2)
#
plot.savefig("./png/1-4.png", format="png", dpi=150)
#
try:
    print('Press Ctrl-C to exit')
    plot.show()
except KeyboardInterrupt:
    # press Ctrl-C to quit
    os.system('clear')
    sys.exit()
# Out:
# [-360.  -359.5 -359.  ...  359.   359.5  360. ]
# [-6.2832 -6.2745 -6.2657 ...  6.2657  6.2745  6.2832]
# [[-6.28320000e+00 -1.46928204e-05]
#  [-6.27450000e+00  8.68519798e-03]
#  [-6.26570000e+00  1.74844162e-02]
#  ...
#  [ 6.26570000e+00 -1.74844162e-02]
#  [ 6.27450000e+00 -8.68519798e-03]
#  [ 6.28320000e+00  1.46928204e-05]]
# [(-6.2832, -1.469282041289069e-05), (-6.2745, 0.008685197984609832), (-6.2657, 0.01748441621198985), (-6.257, 0.026182314867551293), (-6.2483, 0.03487823179619931), (-6.2396, 0.0435715088081349), (-6.2308, 0.05236135099536534), (-6.2221, 0.0610473251638757), (-6.2134, 0.06972867868948922), (-6.2046, 0.07850444625341113), (-6.1959, 0.08717451560273606), (-6.1872, 0.09583798675459332), (-6.1785, 0.10449420397498746), (-6.1697, 0.11324186939007949), (-6.161, 0.12188151155522076), (-6.1523, 0.13051192856693938), (-6.1436, 0.13913246719309383), (-6.1348, 0.14784137679682524), (-6.1261, 0.15644006967529647), (-6.1174, 0.16502692167958058), (-6.1087, 0.17360128287494886), (-6.0999, 0.18226083020496353), (-6.0912, 0.19080810156585673), (-6.0825, 0.19934093075263679), (-6.0737, 0.20795648676695425), (-6.065, 0.2164583106311178), (-6.0563, 0.2249437508690907), (-6.0476, 0.23341216522195143), (-6.0388, 0.24195994255302972), (-6.0301, 0.25039216942978565), (-6.0214, 0.2588054442427781), (-6.0127, 0.267199130195253), (-6.0039, 0.2756687186215355), (-5.9952, 0.2840210790166506), (-5.9865, 0.2923519419918895), (-5.9778, 0.3006606769882127), (-5.969, 0.30904176151334495), (-5.9603, 0.31730408320088654), (-5.9516, 0.3255423882938559), (-5.9428, 0.3338503175180258), (-5.9341, 0.34203842665419637), (-5.9254, 0.3502006470651472), (-5.9167, 0.35833636095631216), (-5.9079, 0.3665379946803116), (