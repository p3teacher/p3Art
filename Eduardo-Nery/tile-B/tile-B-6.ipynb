# %%
# 程式碼A區==程式碼A區==程式碼A區==程式碼A區==程式碼A區
# AAAAAAAA==AAAAAAAA==AAAAAAAAA==AAAAAAAA==AAAAAAAA
#E
# tile-B-6
# 2021-09-18
#
# python 3.8
# run on https://replit.com
# run on ubuntu 16.04 LTS
#
# 要執行本程式, 請按上方run▶
#
# Browser encoding UTF-8 HTML5 URL / as %2F
#
# 程式碼B區==程式碼B區==程式碼B區==程式碼B區==程式碼B區
# BBBBBBBB==BBBBBBBB==BBBBBBBBB==BBBBBBBB==BBBBBBBB
#
# to fix matplotlib warning
import os
os.environ['MPLCONFIGDIR'] = os.getcwd() + "/configs/"
#
# 載入繪圖模組 pyplot, 重新命名為 plot
import matplotlib.pyplot as plot
import numpy as np
from shapely import affinity
from shapely.geometry  import LineString
#
# 定義圖面函數 ------------------------------------------------------
def set_graphic_area(width,height) :
    #    
    cm2inch = 1/2.54    # inch per cm
    #
    # define graphic area
    #
    left_margin = 1.0   # cm
    right_margin = 1.0  # cm
    #
    figure_width  = width  # cm , from xmin to xmax
    figure_height = height # cm , from ymin to ymax
    #
    top_margin = 1.0    # cm
    bottom_margin = 1.0 # cm
    #
    box_width = left_margin + figure_width + right_margin   # cm
    box_height = top_margin + figure_height + bottom_margin # cm
    #
    top_value    = 1.0 - top_margin / box_height
    bottom_value = bottom_margin / box_height
    left_value   = left_margin / box_width
    right_value  = 1.0 - right_margin / box_width
    #
    return (box_width*cm2inch,box_height*cm2inch,top_value,bottom_value,left_value,right_value,width)
#
# end of def
#
# Define the arc
# center position is cxy = (cx, cy)
# start_angle, end_angle is in degrees
#
def shapely_Arc(cxy, r, start_angle, end_angle) :
    #
    numsegments = 1440
    # The coordinates of the arc
    theta = np.radians(np.linspace(start_angle, end_angle, numsegments))
    x = cxy[0] + r * np.cos(theta)
    y = cxy[1] + r * np.sin(theta)
    Arc = LineString(np.column_stack([x, y]))
    return Arc
    #
# end of def
#
def motif_line(LS, COLOR, ZORDER, LINEWIDTH) :
    #
    xs, ys = LS.xy
    ax.plot(xs, ys, color=COLOR, alpha=0.7, linewidth=LINEWIDTH, solid_capstyle='round', zorder=ZORDER)
    return
#
def motif_fill(LS, COLOR, ZORDER, ALPHA) :
    #
    xs, ys = LS.xy
    ax.fill(xs, ys, alpha=ALPHA, closed=True, edgecolor=None, facecolor=COLOR, fill=True, joinstyle='miter', zorder=ZORDER)
    return
#
# 程式碼C區==程式碼C區==程式碼C區==程式碼C區==程式碼C區
# CCCCCCCC==CCCCCCCC==CCCCCCCCC==CCCCCCCC==CCCCCCCC
#
# 設定圖面大小
#  setup圖面大小 (72,72) 單位公分
#  tup7 is type of Tuple, have 7 indexed value
#
# main()
tup7 = set_graphic_area(72,72)  
# 呼叫 pyplot.figure(), 建立一個圖表物件, 並成為目前圖表物件
fig = plot.figure(figsize=(tup7[0], tup7[1])) 
# 圖表的繪圖區域被分為1個子圖, 1 row, 1 column, plot to index 1
ax = fig.add_subplot(1,1,1)   
fig.subplots_adjust(
                top    = tup7[2] ,
                bottom = tup7[3] ,
                left   = tup7[4] ,
                right  = tup7[5] ,
                )
#
plot.xlim(-tup7[6]/2, tup7[6]/2)    # 設定X軸的顯示範圍, from xmin to xmax
plot.ylim(-tup7[6]/2, tup7[6]/2)    # 設定Y軸的顯示範圍, from ymin to ymax
#
xvalues = [-36,-12,0,12,36]
yvalues = [-36,-12,0,12,36]
plot.xticks(xvalues)
plot.yticks(yvalues)
plot.tick_params(labelsize=16)
#
# get current axes, set X,Y same ratio & scale 
plot.gca().set_aspect('equal', adjustable='box')
#
plot.grid(color='green', linewidth=0.5)
ax.grid(True)
# ax.grid(False)
ax.set_axis_on() # will turn on  grid line
# ax.set_axis_off()  # will turn off grid line
#   
plot.savefig("./png/B-6-0.png", format="png", dpi=150)
#

# 程式碼D區==程式碼D區==程式碼D區==程式碼D區==程式碼D區
# DDDDDDDD==DDDDDDDD==DDDDDDDDD==DDDDDDDD==DDDDDDDD
#
A1 = ( 3, 2)
A2 = ( 3, 1)
A3 = ( 3,-1) 
A4 = ( 3,-2)
#
B1 = ( 2, 3)
B2 = ( 1, 3)
B3 = (-1, 3) 
B4 = (-2, 3)
#
line_A1_B1 = LineString([A1, B1])
line_A2_B2 = LineString([A2, B2])
line_A3_B3 = LineString([A3, B3])
line_A4_B4 = LineString([A4, B4])
#
C1 = (1,-3) ; C2 = (0,-2) ; C3 = (-1,-3)
D1 = (2,-3) ; D2 = (0,-1) ; D3 = (-2,-3)
E1 = (-3,1) ; E2 = (-2,0) ; E3 = (-3,-1)
F1 = (-3,2) ; F2 = (-1,0) ; F3 = (-3,-2)
#
line_C = LineString([C1, C2, C3])
line_D = LineString([D1, D2, D3])
line_E = LineString([E1, E2, E3])
line_F = LineString([F1, F2, F3])
#
Y1_zone_xy  = [(3,-3), A4, B4, (-3,3), F1, F2, F3, (-3,-3), D3, D2, D1, (3,-3)]
Y2_zone_xy  = [(3,3), A1, B1, (3,3)]
DB1_zone_xy = [A2, B2, B3, A3, A2]
DB2_zone_xy = [C1, C2, C3, C1]
DB3_zone_xy = [E1, E2, E3, E1]
PB1_zone_xy = [A1, B1, B2, A2, A1]
PB2_zone_xy = [A3, B3, B4, A4, A3]
PB3_zone_xy = [C1, C2, C3, D3, D2, D1, C1]
PB4_zone_xy = [E1, E2, E3, F3, F2, F1, E1]
#
Y1_zone  = LineString(Y1_zone_xy)
Y2_zone  = LineString(Y2_zone_xy)
DB1_zone = LineString(DB1_zone_xy)
DB2_zone = LineString(DB2_zone_xy)
DB3_zone = LineString(DB3_zone_xy)
PB1_zone = LineString(PB1_zone_xy)
PB2_zone = LineString(PB2_zone_xy)
PB3_zone = LineString(PB3_zone_xy)
PB4_zone = LineString(PB4_zone_xy)
#
color_Y  = (244/255,179/255, 36/255)
color_dB = ( 21/255, 55/255,101/255)
color_pB = 'aliceblue'
#
box_xy = [(12,12), (0,12), (0,0), (12,0), (12,12)]
box = LineString(box_xy)
motif_fill(box, 'aliceblue', 20, 1.0)
#
t1 = ( 9, 9)
#
for G in ((Y1_zone, color_Y), 
          (Y2_zone, color_Y),
          (DB1_zone, color_dB),
          (DB2_zone, color_dB),
          (DB3_zone, color_dB) ) :
    # 
    t1G = affinity.translate(G[0], t1[0], t1[1], 0)
    r090_t1G = affinity.rotate(t1G, 90, (6,6))
    r180_t1G = affinity.rotate(t1G,180, (6,6))
    r270_t1G = affinity.rotate(t1G,270, (6,6))
    #
    motif_fill(t1G,      G[1], 30, 1.0)
    motif_fill(r090_t1G, G[1], 30, 1.0)
    motif_fill(r180_t1G, G[1], 30, 1.0)
    motif_fill(r270_t1G, G[1], 30, 1.0)
# end for 
#   
tL = (-12,  0)
tD = (  0,-12)
#
for G in ((Y1_zone, color_Y), 
          (Y2_zone, color_Y),
          (DB1_zone, color_dB),
          (DB2_zone, color_dB),
          (DB3_zone, color_dB) ) :
    # 
    t1G = affinity.translate(G[0], t1[0], t1[1], 0)
    r090_t1G = affinity.rotate(t1G, 90, (6,6))
    r180_t1G = affinity.rotate(t1G,180, (6,6))
    r270_t1G = affinity.rotate(t1G,270, (6,6))
    # ---------------------------------------------------------
    tL_t1G      = affinity.translate(t1G,      tL[0], tL[1], 0)
    tL_r090_t1G = affinity.translate(r090_t1G, tL[0], tL[1], 0)
    tL_r180_t1G = affinity.translate(r180_t1G, tL[0], tL[1], 0)
    tL_r270_t1G = affinity.translate(r270_t1G, tL[0], tL[1], 0)
    #
    motif_fill(tL_t1G,      G[1], 30, 1.0)
    motif_fill(tL_r090_t1G, G[1], 30, 1.0)
    motif_fill(tL_r180_t1G, G[1], 30, 1.0)
    motif_fill(tL_r270_t1G, G[1], 30, 1.0)
    # ---------------------------------------------------------
    tD_t1G      = affinity.translate(t1G,      tD[0], tD[1], 0)
    tD_r090_t1G = affinity.translate(r090_t1G, tD[0], tD[1], 0)
    tD_r180_t1G = affinity.translate(r180_t1G, tD[0], tD[1], 0)
    tD_r270_t1G = affinity.translate(r270_t1G, tD[0], tD[1], 0)
    # 
    motif_fill(tD_t1G,      G[1], 30, 1.0)
    motif_fill(tD_r090_t1G, G[1], 30, 1.0)
    motif_fill(tD_r180_t1G, G[1], 30, 1.0)
    motif_fill(tD_r270_t1G, G[1], 30, 1.0)  
    # ---------------------------------------------------------
    R_t1G      = affinity.rotate(t1G,      180, (0,0))
    R_r090_t1G = affinity.rotate(r090_t1G, 180, (0,0))
    R_r180_t1G = affinity.rotate(r180_t1G, 180, (0,0))
    R_r270_t1G = affinity.rotate(r270_t1G, 180, (0,0))
    #
    motif_fill(R_t1G,      G[1], 30, 1.0)
    motif_fill(R_r090_t1G, G[1], 30, 1.0)
    motif_fill(R_r180_t1G, G[1], 30, 1.0)
    motif_fill(R_r270_t1G, G[1], 30, 1.0)     
# end for 
#   
plot.savefig("./png/B-6-1.png", format="png", dpi=150)
#
T = [(24,0),(24,24),(0,24),(-24,24),(-24,0),(-24,-24),(0,-24),(24,-24)]
#
for G in ((Y1_zone, color_Y), 
          (Y2_zone, color_Y),
          (DB1_zone, color_dB),
          (DB2_zone, color_dB),
          (DB3_zone, color_dB) ) :
    # 
    t1G = affinity.translate(G[0], t1[0], t1[1], 0)
    r090_t1G = affinity.rotate(t1G, 90, (6,6))
    r180_t1G = affinity.rotate(t1G,180, (6,6))
    r270_t1G = affinity.rotate(t1G,270, (6,6))
    # ---------------------------------------------------------
    tL_t1G      = affinity.translate(t1G,      tL[0], tL[1], 0)
    tL_r090_t1G = affinity.translate(r090_t1G, tL[0], tL[1], 0)
    tL_r180_t1G = affinity.translate(r180_t1G, tL[0], tL[1], 0)
    tL_r270_t1G = affinity.translate(r270_t1G, tL[0], tL[1], 0)
    #
    tD_t1G      = affinity.translate(t1G,      tD[0], tD[1], 0)
    tD_r090_t1G = affinity.translate(r090_t1G, tD[0], tD[1], 0)
    tD_r180_t1G = affinity.translate(r180_t1G, tD[0], tD[1], 0)
    tD_r270_t1G = affinity.translate(r270_t1G, tD[0], tD[1], 0)
    # 
    R_t1G      = affinity.rotate(t1G,      180, (0,0))
    R_r090_t1G = affinity.rotate(r090_t1G, 180, (0,0))
    R_r180_t1G = affinity.rotate(r180_t1G, 180, (0,0))
    R_r270_t1G = affinity.rotate(r270_t1G, 180, (0,0))
    #
    for t2 in T :
        t2_t1G      = affinity.translate(t1G,      t2[0], t2[1], 0)
        t2_r090_t1G = affinity.translate(r090_t1G, t2[0], t2[1], 0)
        t2_r180_t1G = affinity.translate(r180_t1G, t2[0], t2[1], 0)
        t2_r270_t1G = affinity.translate(r270_t1G, t2[0], t2[1], 0)
        #
        t2_tL_t1G      = affinity.translate(tL_t1G,      t2[0], t2[1], 0)
        t2_tL_r090_t1G = affinity.translate(tL_r090_t1G, t2[0], t2[1], 0)
        t2_tL_r180_t1G = affinity.translate(tL_r180_t1G, t2[0], t2[1], 0)
        t2_tL_r270_t1G = affinity.translate(tL_r270_t1G, t2[0], t2[1], 0)
        #
        t2_tD_t1G      = affinity.translate(tD_t1G,      t2[0], t2[1], 0)
        t2_tD_r090_t1G = affinity.translate(tD_r090_t1G, t2[0], t2[1], 0)
        t2_tD_r180_t1G = affinity.translate(tD_r180_t1G, t2[0], t2[1], 0)
        t2_tD_r270_t1G = affinity.translate(tD_r270_t1G, t2[0], t2[1], 0)
        #
        t2_R_t1G      = affinity.translate(R_t1G,      t2[0], t2[1], 0)
        t2_R_r090_t1G = affinity.translate(R_r090_t1G, t2[0], t2[1], 0)
        t2_R_r180_t1G = affinity.translate(R_r180_t1G, t2[0], t2[1], 0)
        t2_R_r270_t1G = affinity.translate(R_r270_t1G, t2[0], t2[1], 0)
        #
        motif_fill(t2_t1G,      G[1], 30, 1.0)
        motif_fill(t2_r090_t1G, G[1], 30, 1.0)
        motif_fill(t2_r180_t1G, G[1], 30, 1.0)
        motif_fill(t2_r270_t1G, G[1], 30, 1.0)   
        #
        motif_fill(t2_tL_t1G,      G[1], 30, 1.0)
        motif_fill(t2_tL_r090_t1G, G[1], 30, 1.0)
        motif_fill(t2_tL_r180_t1G, G[1], 30, 1.0)
        motif_fill(t2_tL_r270_t1G, G[1], 30, 1.0)   
        #  
        motif_fill(t2_tD_t1G,      G[1], 30, 1.0)
        motif_fill(t2_tD_r090_t1G, G[1], 30, 1.0)
        motif_fill(t2_tD_r180_t1G, G[1], 30, 1.0)
        motif_fill(t2_tD_r270_t1G, G[1], 30, 1.0)   
        #
        motif_fill(t2_R_t1G,      G[1], 30, 1.0)
        motif_fill(t2_R_r090_t1G, G[1], 30, 1.0)
        motif_fill(t2_R_r180_t1G, G[1], 30, 1.0)
        motif_fill(t2_R_r270_t1G, G[1], 30, 1.0)   
        #         
    # end for
# end for 
#   
plot.savefig("./png/B-6-2.png", format="png", dpi=150)
#
